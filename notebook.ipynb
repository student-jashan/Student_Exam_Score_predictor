# %%
import pandas as pd
df = pd.read_csv('student_habits_performance.csv')

# %%
df.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   object
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   object
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   object
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   object
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    object
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.head(2)
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python311\python.exe

# %%
sns.set(style = "whitegrid")

# %%
df.isna().sum().sum()
# Out:
# np.int64(91)

# %%
df.dropna(inplace = True)

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df.describe()
# Out:
#               age  study_hours_per_day  social_media_hours  netflix_hours  \
# count  909.000000           909.000000          909.000000     909.000000
# mean    20.475248             3.538724            2.504620       1.830363
# std      2.302721             1.469730            1.164802       1.071251
# min     17.000000             0.000000            0.000000       0.000000
# 25%     18.000000             2.500000            1.700000       1.000000
# 50%     20.000000             3.500000            2.500000       1.800000
# 75%     22.000000             4.500000            3.300000       2.600000
# max     24.000000             8.300000            7.200000       5.400000
#
#        attendance_percentage  sleep_hours  exercise_frequency  \
# count             909.000000   909.000000          909.000000
# mean               83.880308     6.474037            3.051705
# std                 9.453622     1.218943            2.035632
# ...

# %%
df.describe(include = "object").columns
# Out:
# Index(['student_id', 'gender', 'part_time_job', 'diet_quality',
#        'parental_education_level', 'internet_quality',
#        'extracurricular_participation'],
#       dtype='object')

# %%
categorical_cols = ["gender","part_time_job","internet_quality","diet_quality","parental_education_level",'extracurricular_participation']

# %%
for col in categorical_cols:
    print(f"value counts for {col}:\n {df[col].value_counts()}\n")
# Out:
# value counts for gender:
#  gender
# Male      440
# Female    433
# Other      36
# Name: count, dtype: int64
#
# value counts for part_time_job:
#  part_time_job
# No     713
# Yes    196
# Name: count, dtype: int64
#
# value counts for internet_quality:
#  internet_quality
# Good       410
# Average    352
# Poor       147
# Name: count, dtype: int64
#
# value counts for diet_quality:
#  diet_quality
# Fair    396
# Good    347
# Poor    166
# Name: count, dtype: int64
#
# value counts for parental_education_level:
#  parental_education_level
# High School    392
# Bachelor       350
# Master         167
# Name: count, dtype: int64
#
# value counts for extracurricular_participation:
#  extracurricular_participation
# No     620
# Yes    289
# Name: count, dtype: int64

# %%
df.hist(bins = 20, figsize = (15,10))
plt.tight_layout()

# %%
for i in categorical_cols:
    sns.countplot(data=df, x=i)
    plt.title(f"Distribution of {i}")
    plt.xticks(rotation=45)
    plt.show()

# %%
sns.heatmap(df.corr(numeric_only =True), annot =True, cmap="coolwarm",fmt = ".2f")
# Out:
# <Axes: >

# %%
df.describe().columns
# Out:
# Index(['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
#        'attendance_percentage', 'sleep_hours', 'exercise_frequency',
#        'mental_health_rating', 'exam_score'],
#       dtype='object')

# %%
num_features = ['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours',
       'attendance_percentage', 'sleep_hours', 'exercise_frequency',
       'mental_health_rating']

# %%
for features in num_features:
    plt.figure()
    sns.scatterplot(data=df, x=features, y = "exam_score")

# %%
for i in categorical_cols:
    plt.figure(figsize=(10,6))
    sns.boxplot(data=df, x=i, y = "exam_score")
    plt.title(f"Exam Score Distribution by {i}")
    plt.xticks(rotation=45)
    plt.show()

# %%
import sys
# !{sys.executable} -m pip install scikit-learn

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.8.0

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
df.columns
# Out:
# Index(['student_id', 'age', 'gender', 'study_hours_per_day',
#        'social_media_hours', 'netflix_hours', 'part_time_job',
#        'attendance_percentage', 'sleep_hours', 'diet_quality',
#        'exercise_frequency', 'parental_education_level', 'internet_quality',
#        'mental_health_rating', 'extracurricular_participation', 'exam_score'],
#       dtype='object')

# %%
features=["study_hours_per_day", "attendance_percentage", "sleep_hours", "part_time_job", "mental_health_rating"]

# %%
target="exam_score"

# %%
df_model=df[features + [target]].copy()

# %%
df_model
# Out:
#      study_hours_per_day  attendance_percentage  sleep_hours part_time_job  \
# 0                    0.0                   85.0          8.0            No
# 1                    6.9                   97.3          4.6            No
# 2                    1.4                   94.8          8.0            No
# 3                    1.0                   71.0          9.2            No
# 4                    5.0                   90.9          4.9            No
# ..                   ...                    ...          ...           ...
# 995                  2.6                   77.0          7.5            No
# 996                  2.9                   86.0          6.8           Yes
# 997                  3.0                   61.9          6.5            No
# 998                  5.4                  100.0          7.6           Yes
# 999                  4.3                   89.4          7.1            No
#
#      mental_health_rating  exam_score
# ...

# %%
le = LabelEncoder()

# %%
df_model = df.copy()

# 1. Handle categorical
df_model["part_time_job"] = df_model["part_time_job"].str.lower()
df_model["part_time_job"] = df_model["part_time_job"].map({"yes": 1, "no": 0})

# %%
df_model["part_time_job"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 995    0
# 996    1
# 997    0
# 998    1
# 999    0
# Name: part_time_job, Length: 909, dtype: int64

# %%
X = df_model[features]

# %%
y = df_model[target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(y_train)
# Out:
# 727

# %%
len(y_test)
# Out:
# 182

# %%
models = {
    "Linear Regression" : {
        "model":LinearRegression(),
        "params":{}
    },
    "Decision Tree" : {
        "model":DecisionTreeRegressor(),
        "params":{
            "max_depth":[3,5,10],
            "min_samples_split":[2,5]
        }
    },
    "Random Forest" : {
        "model":RandomForestRegressor(),
        "params":{
            "n_estimators":[50,100],
            "max_depth":[5,10]
        }
}
}

# %%
best_models = []

# %%
import numpy as np

# %%
for name, config in models.items():
    print(f"Training {name}")

    grid = GridSearchCV(config["model"], config["params"], cv=5, scoring="neg_mean_squared_error")
    grid.fit(X_train,y_train)

    y_pred = grid.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test, y_pred))
    r2 =r2_score(y_test,y_pred)

    best_models.append(
        {
            "model": name,
            "best_params": grid.best_params_,
            "rmse": rmse,
            "r2_score": r2
        }
    )
# Out:
# Training Linear Regression
# Training Decision Tree
# Training Random Forest

# %%
results_df = pd.DataFrame(best_models)

# %%
results_df.sort_values(by="rmse")
# Out:
#                model                               best_params      rmse  \
# 0  Linear Regression                                        {}  7.186681
# 2      Random Forest      {'max_depth': 5, 'n_estimators': 50}  7.555225
# 1      Decision Tree  {'max_depth': 5, 'min_samples_split': 2}  8.458302
#
#    r2_score
# 0  0.794925
# 2  0.773353
# 1  0.715932

# %%
import joblib
best_row = results_df.sort_values(by="rmse").iloc[0]

# %%
best_row
# Out:
# model          Linear Regression
# best_params                   {}
# rmse                    7.186681
# r2_score                0.794925
# Name: 0, dtype: object

# %%
best_model_name = best_row['model']

# %%
best_model_name
# Out:
# 'Linear Regression'

# %%
best_model_config = models[best_model_name]

# %%
best_model_config
# Out:
# {'model': LinearRegression(), 'params': {}}

# %%
final_model = best_model_config["model"]

# %%
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
joblib.dump(final_model, "final_student_performance_model.pkl")
# Out:
# ['final_student_performance_model.pkl']

# %%
joblib.load("final_student_performance_model.pkl").predict(X_test)
# Out:
# array([ 55.14195272,  54.22024198,  74.47177811,  55.22074637,
#         86.51178448, 101.01138266,  86.92298316,  69.35389946,
#         60.6209758 ,  48.1785658 ,  64.38337437,  66.95712198,
#         79.7245903 ,  79.98469099,  66.71216009,  91.49334267,
#         73.1673932 ,  46.38528027,  73.73470842,  65.33003352,
#         70.99577013,  97.86319106,  54.77872093,  66.75598134,
#         67.28188611,  70.1122084 ,  79.37860514,  93.42662897,
#         56.4052808 ,  68.67625259,  63.46863323,  74.53698275,
#         87.66820478,  41.50768325,  77.0077602 ,  58.71341382,
#         58.02616961,  75.44613378,  37.5268067 , 102.05443373,
#         83.39081928,  73.87388264,  76.62284649,  63.44842876,
#         90.63779187,  78.93711347,  91.82549796,  63.42570115,
#         55.03445016,  73.66672527,  73.39898863,  79.94294863,
#         54.26161987,  53.00815757,  63.74810186,  35.05873964,
#         78.30936564,  60.05075545,  85.15391158,  69.85675881,
# ...

# %%
best_rf = grid.best_estimator_

# %%
y_pred = best_rf.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 2
#       1 y_pred = best_rf.predict(X_test)
# ----> 2 print(classification_report(y_test, y_pred))
#
# NameError: name 'classification_report' is not defined
